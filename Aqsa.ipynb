# %% [markdown]
# <a href="https://colab.research.google.com/github/TouseefDataScientist/Machine-learning2/blob/main/Aqsa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Installing Pandas**

# %%
# %pip install pandas

# %% [markdown]
# **Import Pandas**

# %%
import pandas as pd

# %% [markdown]
# **Basic Data Structure in pandas**
# **DataFrame , Series**

# %%
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
a= pd.DataFrame({'Age':[21, 29,29,39,45],'Salary':[15000, 8000, 6000,5000,12000]})

# %%
print(a)
# Out:
#    Age  Salary
# 0   21   15000
# 1   29    8000
# 2   29    6000
# 3   39    5000
# 4   45   12000

# %%
import numpy as np

# %% [markdown]
# **Installing Numpy**

# %%
# %pip install numpy

# %%
import numpy as np

# %% [markdown]
# **Data Structure in Series**

# %%
 b= pd.Series({'Age':[21, 29,29,39,45],'Salary':[15000, 8000, 6000,5000,12000]})

# %%
print(b)
# Out:
# Age                   [21, 29, 29, 39, 45]
# Salary    [15000, 8000, 6000, 5000, 12000]
# dtype: object

# %%
c= pd.Series([21, 29,29,39,45, 15000, 8000, 6000,5000,12000])

# %%
print(c)
# Out:
# 0       21
# 1       29
# 2       29
# 3       39
# 4       45
# 5    15000
# 6     8000
# 7     6000
# 8     5000
# 9    12000
# dtype: int64

# %% [markdown]
# **Object Creation**

# %%
dates = pd.date_range('20130101', periods=6)

# %%
print(dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df= pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
print(df)
# Out:
#                    A         B         C         D
# 2013-01-01  1.862696  0.290902  0.496978  0.421576
# 2013-01-02 -0.127783  0.869737 -0.997292  0.855947
# 2013-01-03  0.478888 -0.323510 -0.467562  0.009812
# 2013-01-04 -1.040271  0.020321 -0.273301 -0.382300
# 2013-01-05  0.416687 -0.976808  1.359549  1.012754
# 2013-01-06 -1.036494 -0.984998 -0.575861  0.324363

# %%
import pandas as pd
import numpy as np

# %%
 df2 = pd.DataFrame(
   ...:     {
   ...:         "A": 1.0,
   ...:         "B": pd.Timestamp("20130101"),
   ...:         "C": pd.Series(1, index=list(range(4))),
   ...:         "D": np.array([3] * 4, dtype="int32"),
   ...:         "E": pd.Categorical(["Pizza", "Burger", "Fries", "Cocacola"]),
   ...:         "F": "foo",
   ...:     }
   ...: )
   ...:

 df2
# Out:
#      A          B  C  D         E    F
# 0  1.0 2013-01-01  1  3     Pizza  foo
# 1  1.0 2013-01-01  1  3    Burger  foo
# 2  1.0 2013-01-01  1  3     Fries  foo
# 3  1.0 2013-01-01  1  3  Cocacola  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C            int64
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.862696  0.290902  0.496978  0.421576
# 2013-01-02 -0.127783  0.869737 -0.997292  0.855947
# 2013-01-03  0.478888 -0.323510 -0.467562  0.009812
# 2013-01-04 -1.040271  0.020321 -0.273301 -0.382300
# 2013-01-05  0.416687 -0.976808  1.359549  1.012754

# %%
df.tail(4)
# Out:
#                    A         B         C         D
# 2013-01-03  0.478888 -0.323510 -0.467562  0.009812
# 2013-01-04 -1.040271  0.020321 -0.273301 -0.382300
# 2013-01-05  0.416687 -0.976808  1.359549  1.012754
# 2013-01-06 -1.036494 -0.984998 -0.575861  0.324363

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 1.86269563,  0.29090217,  0.49697785,  0.42157593],
#        [-0.1277828 ,  0.86973745, -0.99729183,  0.85594673],
#        [ 0.47888811, -0.32351037, -0.46756158,  0.00981165],
#        [-1.04027124,  0.02032121, -0.27330084, -0.38229971],
#        [ 0.41668716, -0.97680763,  1.3595488 ,  1.0127545 ],
#        [-1.03649445, -0.9849977 , -0.57586134,  0.32436252]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C            int64
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-01 00:00:00'), 1, 3, 'Pizza', 'foo'],
#        [1.0, Timestamp('2013-01-01 00:00:00'), 1, 3, 'Burger', 'foo'],
#        [1.0, Timestamp('2013-01-01 00:00:00'), 1, 3, 'Fries', 'foo'],
#        [1.0, Timestamp('2013-01-01 00:00:00'), 1, 3, 'Cocacola', 'foo']],
#       dtype=object)

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.862696   -0.127783    0.478888   -1.040271    0.416687   -1.036494
# B    0.290902    0.869737   -0.323510    0.020321   -0.976808   -0.984998
# C    0.496978   -0.997292   -0.467562   -0.273301    1.359549   -0.575861
# D    0.421576    0.855947    0.009812   -0.382300    1.012754    0.324363

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.421576  0.496978  0.290902  1.862696
# 2013-01-02  0.855947 -0.997292  0.869737 -0.127783
# 2013-01-03  0.009812 -0.467562 -0.323510  0.478888
# 2013-01-04 -0.382300 -0.273301  0.020321 -1.040271
# 2013-01-05  1.012754  1.359549 -0.976808  0.416687
# 2013-01-06  0.324363 -0.575861 -0.984998 -1.036494

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  1.862696  0.290902  0.496978  0.421576
# 2013-01-02 -0.127783  0.869737 -0.997292  0.855947
# 2013-01-03  0.478888 -0.323510 -0.467562  0.009812
# 2013-01-04 -1.040271  0.020321 -0.273301 -0.382300
# 2013-01-05  0.416687 -0.976808  1.359549  1.012754
# 2013-01-06 -1.036494 -0.984998 -0.575861  0.324363

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-06 -1.036494 -0.984998 -0.575861  0.324363
# 2013-01-05  0.416687 -0.976808  1.359549  1.012754
# 2013-01-03  0.478888 -0.323510 -0.467562  0.009812
# 2013-01-04 -1.040271  0.020321 -0.273301 -0.382300
# 2013-01-01  1.862696  0.290902  0.496978  0.421576
# 2013-01-02 -0.127783  0.869737 -0.997292  0.855947

# %%
df["B"]
# Out:
# 2013-01-01    0.290902
# 2013-01-02    0.869737
# 2013-01-03   -0.323510
# 2013-01-04    0.020321
# 2013-01-05   -0.976808
# 2013-01-06   -0.984998
# Freq: D, Name: B, dtype: float64

# %%
df[1:3]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.127783  0.869737 -0.997292  0.855947
# 2013-01-03  0.478888 -0.323510 -0.467562  0.009812
