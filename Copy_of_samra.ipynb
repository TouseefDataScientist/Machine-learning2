# %% [markdown]
# <a href="https://colab.research.google.com/github/TouseefDataScientist/Machine-learning2/blob/main/Copy_of_samra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pandas

# %%
import pandas as pd
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
s= pd.DataFrame({'Age':[22,33,45,66,22],'Salary':[12000,33000,45000,15000,23000]})

# %%
print(s)
# Out:
#    Age  Salary
# 0   22   12000
# 1   33   33000
# 2   45   45000
# 3   66   15000
# 4   22   23000

# %%
In [1]: import numpy as np

# %%
 a = pd.Series([15, 13, 25, 22, 6, 8, np.nan])
print(a)
# Out:
# 0    15.0
# 1    13.0
# 2    25.0
# 3    22.0
# 4     6.0
# 5     8.0
# 6     NaN
# dtype: float64

# %%
 dates = pd.date_range("20231203", periods=7)

# %%
print(dates)
# Out:
# DatetimeIndex(['2023-12-03', '2023-12-04', '2023-12-05', '2023-12-06',
#                '2023-12-07', '2023-12-08', '2023-12-09'],
#               dtype='datetime64[ns]', freq='D')

# %%
 df = pd.DataFrame(np.random.randn(7, 4), index=dates, columns=list("abcd"))

# %%
print(df)
# Out:
#                    a         b         c         d
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103
# 2023-12-06  0.959499  0.020501 -0.923947 -1.279367
# 2023-12-07  1.223082  0.506502 -0.869519  1.161320
# 2023-12-08 -1.563805 -0.501219 -1.504628 -0.644253
# 2023-12-09 -1.022425  0.734417 -0.281873  0.506132

# %%
In [9]: df2 = pd.DataFrame(
   ...:     {
   ...:         "A": 1.0,
   ...:         "B": pd.Timestamp("20231203"),
   ...:         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
   ...:         "D": np.array([3] * 4, dtype="int32"),
   ...:         "E": pd.Categorical(["age", "salary", "age", "salary"]),
   ...:         "F": "all",
   ...:     }
   ...: )

# %%
df2
# Out:
#      A          B    C  D       E    F
# 0  1.0 2023-12-03  1.0  3     age  foo
# 1  1.0 2023-12-03  1.0  3  salary  foo
# 2  1.0 2023-12-03  1.0  3     age  foo
# 3  1.0 2023-12-03  1.0  3  salary  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()
# Out:
#                    a         b         c         d
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103
# 2023-12-06  0.959499  0.020501 -0.923947 -1.279367
# 2023-12-07  1.223082  0.506502 -0.869519  1.161320

# %%
df.head(4)
# Out:
#                    a         b         c         d
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103
# 2023-12-06  0.959499  0.020501 -0.923947 -1.279367

# %%
df.tail(2)
# Out:
#                    a         b         c         d
# 2023-12-08 -1.563805 -0.501219 -1.504628 -0.644253
# 2023-12-09 -1.022425  0.734417 -0.281873  0.506132

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
import numpy as pd

# %%
df.to_numpy()
# Out:
# array([[ 0.22046975,  0.53119005, -1.3202874 ,  0.29705212],
#        [ 1.08504791, -0.7330835 , -1.15153884, -1.82940524],
#        [ 0.10704953,  0.61983621,  0.86387217, -0.62410279],
#        [ 0.95949943,  0.02050108, -0.9239469 , -1.27936678],
#        [ 1.223082  ,  0.50650234, -0.86951915,  1.16132027],
#        [-1.56380548, -0.50121946, -1.50462796, -0.64425322],
#        [-1.02242469,  0.73441691, -0.28187347,  0.50613206]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-12-03 00:00:00'), 1.0, 3, 'age', 'foo'],
#        [1.0, Timestamp('2023-12-03 00:00:00'), 1.0, 3, 'salary', 'foo'],
#        [1.0, Timestamp('2023-12-03 00:00:00'), 1.0, 3, 'age', 'foo'],
#        [1.0, Timestamp('2023-12-03 00:00:00'), 1.0, 3, 'salary', 'foo']],
#       dtype=object)

# %%
df.T
# Out:
#    2023-12-03  2023-12-04  2023-12-05  2023-12-06  2023-12-07  2023-12-08  \
# a    0.220470    1.085048    0.107050    0.959499    1.223082   -1.563805
# b    0.531190   -0.733084    0.619836    0.020501    0.506502   -0.501219
# c   -1.320287   -1.151539    0.863872   -0.923947   -0.869519   -1.504628
# d    0.297052   -1.829405   -0.624103   -1.279367    1.161320   -0.644253
#
#    2023-12-09
# a   -1.022425
# b    0.734417
# c   -0.281873
# d    0.506132

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    d         c         b         a
# 2023-12-03  0.297052 -1.320287  0.531190  0.220470
# 2023-12-04 -1.829405 -1.151539 -0.733084  1.085048
# 2023-12-05 -0.624103  0.863872  0.619836  0.107050
# 2023-12-06 -1.279367 -0.923947  0.020501  0.959499
# 2023-12-07  1.161320 -0.869519  0.506502  1.223082
# 2023-12-08 -0.644253 -1.504628 -0.501219 -1.563805
# 2023-12-09  0.506132 -0.281873  0.734417 -1.022425

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    a         b         c         d
# 2023-12-09 -1.022425  0.734417 -0.281873  0.506132
# 2023-12-08 -1.563805 -0.501219 -1.504628 -0.644253
# 2023-12-07  1.223082  0.506502 -0.869519  1.161320
# 2023-12-06  0.959499  0.020501 -0.923947 -1.279367
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    a         b         c         d
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103
# 2023-12-06  0.959499  0.020501 -0.923947 -1.279367
# 2023-12-07  1.223082  0.506502 -0.869519  1.161320
# 2023-12-08 -1.563805 -0.501219 -1.504628 -0.644253
# 2023-12-09 -1.022425  0.734417 -0.281873  0.506132

# %%
df.sort_values(by="c")
# Out:
#                    a         b         c         d
# 2023-12-08 -1.563805 -0.501219 -1.504628 -0.644253
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-06  0.959499  0.020501 -0.923947 -1.279367
# 2023-12-07  1.223082  0.506502 -0.869519  1.161320
# 2023-12-09 -1.022425  0.734417 -0.281873  0.506132
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103

# %%
df["b"]
# Out:
# 2023-12-03    0.531190
# 2023-12-04   -0.733084
# 2023-12-05    0.619836
# 2023-12-06    0.020501
# 2023-12-07    0.506502
# 2023-12-08   -0.501219
# 2023-12-09    0.734417
# Freq: D, Name: b, dtype: float64

# %%
df[1:3]
# Out:
#                    a         b         c         d
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103

# %%
df["20231203":"20231205"]
# Out:
#                    a         b         c         d
# 2023-12-03  0.220470  0.531190 -1.320287  0.297052
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103

# %%
df.loc[dates[1]]
# Out:
# a    1.085048
# b   -0.733084
# c   -1.151539
# d   -1.829405
# Name: 2023-12-04 00:00:00, dtype: float64

# %%
df.loc[:, ["c", "d"]]
# Out:
#                    c         d
# 2023-12-03 -1.320287  0.297052
# 2023-12-04 -1.151539 -1.829405
# 2023-12-05  0.863872 -0.624103
# 2023-12-06 -0.923947 -1.279367
# 2023-12-07 -0.869519  1.161320
# 2023-12-08 -1.504628 -0.644253
# 2023-12-09 -0.281873  0.506132

# %%
df.loc["20231203":"20231205", ["a", "b"]]
# Out:
#                    a         b
# 2023-12-03  0.220470  0.531190
# 2023-12-04  1.085048 -0.733084
# 2023-12-05  0.107050  0.619836

# %%
df.at[dates[1], "b"]
# Out:
# -0.7330835012039351

# %%
df.iloc[1:3, :]
# Out:
#                    a         b         c         d
# 2023-12-04  1.085048 -0.733084 -1.151539 -1.829405
# 2023-12-05  0.107050  0.619836  0.863872 -0.624103

# %%
df.iat[1, 1]
# Out:
# -0.7330835012039351

# %%
df[df["c"] > 1]
# Out:
# Empty DataFrame
# Columns: [a, b, c, d]
# Index: []

# %%
df[df["c"] > 0]
# Out:
#                   a         b         c         d
# 2023-12-05  0.10705  0.619836  0.863872 -0.624103

# %%
df[df > 0]
# Out:
#                    a         b         c         d
# 2023-12-03  0.220470  0.531190       NaN  0.297052
# 2023-12-04  1.085048       NaN       NaN       NaN
# 2023-12-05  0.107050  0.619836  0.863872       NaN
# 2023-12-06  0.959499  0.020501       NaN       NaN
# 2023-12-07  1.223082  0.506502       NaN  1.161320
# 2023-12-08       NaN       NaN       NaN       NaN
# 2023-12-09       NaN  0.734417       NaN  0.506132
