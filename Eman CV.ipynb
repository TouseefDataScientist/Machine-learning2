# %% [markdown]
# # Eman Ahmad
# **Bussiness Information Techonology**
# [Email][(emanahmad2618@gmail.com)] | [GitHub](https://github.com/E32546)
#
# ---
#
# ## **Skills**
# - **Programming Languages:** Python, Java, Flutter
# - **Tools:** VS Code, Android Studio, Atom, MS Word, MS Excel, PowerPoint
# ---
#
# ## **Education**
# | **University**    | College    | School    |
# |:-----------:|:-----------:|:-----------:|
# | VIRTUAL UNIVERSITY, Rwp | Punjab GOVT College for Women, Rwp
#
# ---
#
# ## **Certifications**
# - Artifical Intelligence and Machine Learning
# - Virtual Assistant
#
# ---
#
#
# ## **Languages**
# - English (Fluent)
# - Urdu (Native)
#
# ---
#
# ## **Interpretational Skills**
#
# - Multitasking Abilities
# - Teamwork and Collaboration
# - Planning and Coordination
# - Excellent Communication
#
# ---
#
# <style>
#   body {
#     font-family: Arial, sans-serif;
#     line-height: 1.6;
#     color: #333;
#   }
#   h1, h2 {
#     color: #2c3e50;
#   }
#   a {
#     color: #2980b9;
#     text-decoration: none;
#   }
#   a:hover {
#     text-decoration: underline;
#   }
#   ul {
#     margin: 10px 0;
#     padding: 0 20px;
#   }
#   .certifications, .languages {
#     display: flex;
#     flex-direction: column;
#   }
# </style>
