# %% [markdown]
# # Intro
# <center/>
# ### ** Name:*Eman AHMAD**
# **BBIT**
# - [Email]-(emanahmad2618@gmail.com)
# - [GitHub]-(https://github.com/E32546)
# - <center/>

# %%
#Install Libraries 
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries
import pandas as pd

# %% [markdown]
# Loading Dataset

# %%
#loading CSV file
pd.read_csv("book1.csv")
# Out:
#         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0

# %%
df=pd.read_csv('book1.csv')

# %% [markdown]
# Prewive data set

# %%
df
# Out:
#         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0

# %%
#install Excel libraries
# %pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#loading CSV file
pd.read_excel("book1.xlsx")
# Out:
#         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0

# %%
df.head(1)
# Out:
#        Name Destination Gender   Age    Salary
# 0  Mukhatir   Professor      M  37.0  115000.0

# %%
df.tail(2)
# Out:
#       Name Destination Gender   Age    Salary
# 15  Qaisar   professor      M  20.0  170000.0
# 16   Wajid    Engineer      M  85.0  190000.0

# %%
df.T
# Out:
#                     0        1         2        3          4          5   \
# Name          Mukhatir    Azziz    Moshin   Naveed      Babar       Aqsa
# Destination  Professor  Teacher  ENGINEER  Analyst   Engineer  Scientist
# Gender               M        M         M        F          F          F
# Age               37.0     30.0      29.0     30.0       25.0       22.0
# Salary        115000.0  35000.0   50000.0  70000.0  1500000.0        NaN
#
#                   6          7         8         9          10        11  \
# Name           Rafia      Samra      Eman  Abdullah      Mosib     Ahmed
# Destination  Analyst  Scientist  Engineer   Teacher  professor  engineer
# Gender             F          F         F         M          M         M
# Age             29.0       26.0      28.0      55.0       60.0       NaN
# Salary       20000.0   115000.0   35000.0       NaN    70000.0   90000.0
#
#                    12       13       14         15        16
# ...

# %%
df.aggregate
# Out:
# <bound method DataFrame.aggregate of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.abs
# Out:
# <bound method NDFrame.abs of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.add_prefix
# Out:
# <bound method NDFrame.add_prefix of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.add_suffix
# Out:
# <bound method NDFrame.add_suffix of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.agg
# Out:
# <bound method DataFrame.aggregate of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.median
# Out:
# <bound method DataFrame.median of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.from_dict
# Out:
# <bound method DataFrame.from_dict of <class 'pandas.core.frame.DataFrame'>>

# %%
df.mean
# Out:
# <bound method DataFrame.mean of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.truncate
# Out:
# <bound method NDFrame.truncate of         Name Destination Gender    Age     Salary
# 0   Mukhatir   Professor      M   37.0   115000.0
# 1      Azziz     Teacher      M   30.0    35000.0
# 2     Moshin    ENGINEER      M   29.0    50000.0
# 3     Naveed     Analyst      F   30.0    70000.0
# 4      Babar    Engineer      F   25.0  1500000.0
# 5       Aqsa   Scientist      F   22.0        NaN
# 6      Rafia     Analyst      F   29.0    20000.0
# 7      Samra   Scientist      F   26.0   115000.0
# 8       Eman    Engineer      F   28.0    35000.0
# 9   Abdullah     Teacher      M   55.0        NaN
# 10     Mosib   professor      M   60.0    70000.0
# 11     Ahmed    engineer      M    NaN    90000.0
# 12     Ashan     trainer      M  156.0   110000.0
# 13     Wajid     teacher      M   67.0     2000.0
# 14     Naeem     tranier      M   80.0    16000.0
# 15    Qaisar   professor      M   20.0   170000.0
# 16     Wajid    Engineer      M   85.0   190000.0>

# %%
df.loc[8:9]
# Out:
#        Name Destination Gender   Age   Salary
# 8      Eman    Engineer      F  28.0  35000.0
# 9  Abdullah     Teacher      M  55.0      NaN

# %%
import json

# %%
with open("sample1.json", "r") as file:
    data = json.load(file)

# %%
print(data)
# Out:
# {'fruit': 'Apple', 'size': 'Large', 'color': 'Red'}

# %%
# %pip install pymupdf
# Out:
# ...
#    ---------------------------------------- 0.0/16.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.6 MB 1.7 MB/s eta 0:00:10
#    - -------------------------------------- 0.8/16.6 MB 1.2 MB/s eta 0:00:14
#    -- ------------------------------------- 1.0/16.6 MB 1.1 MB/s eta 0:00:14
#    -- ------------------------------------- 1.0/16.6 MB 1.1 MB/s eta 0:00:14
#    --- ------------------------------------ 1.3/16.6 MB 1.1 MB/s eta 0:00:15
#    --- ------------------------------------ 1.6/16.6 MB 1.0 MB/s eta 0:00:15
#    --- ------------------------------------ 1.6/16.6 MB 1.0 MB/s eta 0:00:15
#    ---- ----------------------------------- 1.8/16.6 MB 945.6 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.8/16.6 MB 945.6 kB/s eta 0:00:16
# ...

# %%
import pymupdf as pdf

# %%
import fitz

# %%
fitz.open ("sample.pdf")
# Out:
# Document('sample.pdf')

# %%
pdf = fitz.open("sample.pdf")

# %%
page= pdf.load_page(0)

# %%
text= page.get_text()

# %%
print(text)
# Out:
# Sample PDF
# This is a simple PDF ﬁle. Fun fun fun.
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Phasellus facilisis odio sed mi.
# Curabitur suscipit. Nullam vel nisi. Etiam semper ipsum ut lectus. Proin aliquam, erat eget
# pharetra commodo, eros mi condimentum quam, sed commodo justo quam ut velit.
# Integer a erat. Cras laoreet ligula cursus enim. Aenean scelerisque velit et tellus.
# Vestibulum dictum aliquet sem. Nulla facilisi. Vestibulum accumsan ante vitae elit. Nulla
# erat dolor, blandit in, rutrum quis, semper pulvinar, enim. Nullam varius congue risus.
# Vivamus sollicitudin, metus ut interdum eleifend, nisi tellus pellentesque elit, tristique
# accumsan eros quam et risus. Suspendisse libero odio, mattis sit amet, aliquet eget,
# hendrerit vel, nulla. Sed vitae augue. Aliquam erat volutpat. Aliquam feugiat vulputate nisl.
# Suspendisse quis nulla pretium ante pretium mollis. Proin velit ligula, sagittis at, egestas a,
# pulvinar quis, nisl.
# ...

# %%
# %pip install python_docx
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 453.0 kB/s eta 0:00:08
#    ----- ---------------------------------- 0.5/3.8 MB 453.0 kB/s eta 0:00:08
#    ----- ---------------------------------- 0.5/3.8 MB 453.0 kB/s eta 0:00:08
#    ----- ---------------------------------- 0.5/3.8 MB 453.0 kB/s eta 0:00:08
#    ----- ---------------------------------- 0.5/3.8 MB 453.0 kB/s eta 0:00:08
#    -------- ------------------------------- 0.8/3.8 MB 335.1 kB/s eta 0:00:10
#    -------- ------------------------------- 0.8/3.8 MB 335.1 kB/s eta 0:00:10
#    -------- ------------------------------- 0.8/3.8 MB 335.1 kB/s eta 0:00:10
# ...

# %%
from docx import Document

# %%
document= Document ("demo.docx")

# %%
print (document.paragraphs)
# Out:
# [<docx.text.paragraph.Paragraph object at 0x000002653BEC9BE0>, <docx.text.paragraph.Paragraph object at 0x000002653BEE87D0>, <docx.text.paragraph.Paragraph object at 0x000002653BEE9BD0>, <docx.text.paragraph.Paragraph object at 0x0000026539CCDCD0>, <docx.text.paragraph.Paragraph object at 0x000002653BEC48A0>, <docx.text.paragraph.Paragraph object at 0x000002653A1CD5B0>, <docx.text.paragraph.Paragraph object at 0x000002653BEEE250>, <docx.text.paragraph.Paragraph object at 0x000002653BEEE470>, <docx.text.paragraph.Paragraph object at 0x000002653A766250>, <docx.text.paragraph.Paragraph object at 0x000002653A766B50>, <docx.text.paragraph.Paragraph object at 0x000002653BF549B0>, <docx.text.paragraph.Paragraph object at 0x000002653BF55B80>, <docx.text.paragraph.Paragraph object at 0x000002653BEAE270>, <docx.text.paragraph.Paragraph object at 0x000002653BEAE5F0>, <docx.text.paragraph.Paragraph object at 0x000002653BF7DBF0>, <docx.text.paragraph.Paragraph object at 0x000002653A23BF50>, <docx
# ...

# %%
for p in document.paragraphs:
    print(p.text)
# Out:
# Demonstration of DOCX support in calibre
# This document demonstrates the ability of the calibre DOCX Input plugin to convert the various typographic features in a Microsoft Word (2007 and newer) document. Convert this document to a modern ebook format, such as AZW3 for Kindles or EPUB for other ebook readers, to see it in action.
# There is support for images, tables, lists, footnotes, endnotes, links, dropcaps and various types of text and paragraph level formatting.
# To see the DOCX conversion in action, simply add this file to calibre using the “Add Books” button and then click “Convert”.  Set the output format in the top right corner of the conversion dialog to EPUB or AZW3 and click “OK”.
#
# Text Formatting
# Inline formatting
# Here, we demonstrate various types of inline text formatting and the use of embedded fonts.
# ...
