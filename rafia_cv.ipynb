# %% [markdown]
# <img src="pp.jpg" alt="Profile Image" width="120" height="120" style="float: left; margin-right: 20px; border-radius: 50%;">
#
#
# # Rafia Hasnain
# **Computer Science**
# [Email](mailto:rafiahsnn@gmail.com) | [LinkedIn](www.linkedin.com/in/rafia-hasnain-b64345263) | [GitHub](https://github.com/rafihsnn)
#
# ---
#
# ## 🧑‍💻 **Professional Summary**
# To make a sound position in the corporate world and work enthusiastically to achieve the goal of the organization with devotion, hard work and polish my technical Skills.
#
# ---
#
# ## 🛠 **Skills**
# - **Programming Languages:** Python, Java, Flutter
# - **Tools:** VS Code, Android Studio, Atom, MS Word, MS Excel, PowerPoint
# ---
#
# ## 🎓 **Education**
# | **University**    | College    | School    |
# |:-----------:|:-----------:|:-----------:|
# | ARID Agriculture University, Rwp | Punjab College for Women, Rwp | IMSG (I-8/1) |
# | (2019-2023) | (2017-2019) | (2013-2017) |
#
# ---
#
# ## 📜 **Certifications**
# - Participated in 1 Day Artificial Intelligence Workshop
# - Participated in 1 Day Big Data Analytics Workshop
#
# ---
#
# ## 🌟 **Projects**
#
# ### **Final Year Project**
#
# Online Oasis “Embedding Augmented Reality in Online Shopping System”
#
# Description:
#
# Worked on Flutter framework to embed Augmented Reality in E-commerce applications.
# Allowing customers to virtually experience products before purchasing.
# Utilized AR technology to enable users to visualize products in 3D.
#
# ### **Semester Project**
#
# Book Store Web Application
#
# ---
#
# ## 🌐 **Languages**
# - English (Fluent)
#
# ---
#
# ## 💡 **Interpretational Skills**
#
# - Multitasking Abilities
# - Teamwork and Collaboration
# - Planning and Coordination
# - Excellent Communication
#
# ---
#
# <style>
#   body {
#     font-family: Arial, sans-serif;
#     line-height: 1.6;
#     color: #333;
#   }
#   h1, h2 {
#     color: #2c3e50;
#   }
#   a {
#     color: #2980b9;
#     text-decoration: none;
#   }
#   a:hover {
#     text-decoration: underline;
#   }
#   ul {
#     margin: 10px 0;
#     padding: 0 20px;
#   }
#   .certifications, .languages {
#     display: flex;
#     flex-direction: column;
#   }
# </style>
