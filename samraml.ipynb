# %% [markdown]
# ## 26 dec today task (employee dataset)

# %%
#loading libraries
# %pip install panads
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement panads (from versions: none)
# ERROR: No matching distribution found for panads

# %%
#import libraries

# %%
import pandas as pd

# %%
#loading dataset
pd.read_csv("EXCEL.csv")
# Out:
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 1     AZIZ   30      M    35000.0     TEACHER
# 2   mohsin   29      M    50000.0    ENGINEER
# 3   naveed   30      F    70000.0     ANALYST
# 4    babar   25      M  1500000.0    ENGINEER
# 5     aqsa   22      F        NaN   SCIENTIST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %%
#load data in variable
s= pd.read_csv("EXCEL.CSV")

# %%
#Excel file
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel("EXCEL.xlsx")
# Out:
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 1     AZIZ   30      M    35000.0     TEACHER
# 2   mohsin   29      M    50000.0    ENGINEER
# 3   naveed   30      F    70000.0     ANALYST
# 4    babar   25      M  1500000.0    ENGINEER
# 5     aqsa   22      F        NaN   SCIENTIST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %%
a= pd.read_excel("EXCEL.xlsx")

# %%
#preview the data using print function
print("preview the data using print function")
print(a)
# Out:
# preview the data using print function
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 1     AZIZ   30      M    35000.0     TEACHER
# 2   mohsin   29      M    50000.0    ENGINEER
# 3   naveed   30      F    70000.0     ANALYST
# 4    babar   25      M  1500000.0    ENGINEER
# 5     aqsa   22      F        NaN   SCIENTIST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %%
a
# Out:
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 1     AZIZ   30      M    35000.0     TEACHER
# 2   mohsin   29      M    50000.0    ENGINEER
# 3   naveed   30      F    70000.0     ANALYST
# 4    babar   25      M  1500000.0    ENGINEER
# 5     aqsa   22      F        NaN   SCIENTIST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %%
#dispaly teh top row
a.head(3)
# Out:
#       Name  Age gender    salary DESIGNATION
# 0  Mukhtar   37      M  115000.0   PROFESSOR
# 1     AZIZ   30      M   35000.0     TEACHER
# 2   mohsin   29      M   50000.0    ENGINEER

# %%
#display the bottom rows
a.tail(3)
# Out:
#     Name  Age gender     salary DESIGNATION
# 6  rafia   29      F    20000.0     ANALYST
# 7  samra   26      F  1500000.0   SCIENTIST
# 8   eman   26      F    35000.0    ENGINEER

# %%
#display the middle rows
a.loc[3:4]
# Out:
#      Name  Age gender     salary DESIGNATION
# 3  naveed   30      F    70000.0     ANALYST
# 4   babar   25      M  1500000.0    ENGINEER

# %%
#showing coloum
a["salary"]
# Out:
# 0     115000.0
# 1      35000.0
# 2      50000.0
# 3      70000.0
# 4    1500000.0
# 5          NaN
# 6      20000.0
# 7    1500000.0
# 8      35000.0
# Name: salary, dtype: float64

# %%
#showing multiple coloumn
a[["Age","salary"]]
# Out:
#    Age     salary
# 0   37   115000.0
# 1   30    35000.0
# 2   29    50000.0
# 3   30    70000.0
# 4   25  1500000.0
# 5   22        NaN
# 6   29    20000.0
# 7   26  1500000.0
# 8   26    35000.0

# %%
#filtering
a.loc[a["Age"]>25]
# Out:
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 1     AZIZ   30      M    35000.0     TEACHER
# 2   mohsin   29      M    50000.0    ENGINEER
# 3   naveed   30      F    70000.0     ANALYST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %% [markdown]
# ## sorting

# %%
a.sort_values(by="Name")
# Out:
#       Name  Age gender     salary DESIGNATION
# 1     AZIZ   30      M    35000.0     TEACHER
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 5     aqsa   22      F        NaN   SCIENTIST
# 4    babar   25      M  1500000.0    ENGINEER
# 8     eman   26      F    35000.0    ENGINEER
# 2   mohsin   29      M    50000.0    ENGINEER
# 3   naveed   30      F    70000.0     ANALYST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST

# %% [markdown]
# ## grouping

# %%
a.groupby('Age')['Age'].mean()
# Out:
# Age
# 22    22.0
# 25    25.0
# 26    26.0
# 29    29.0
# 30    30.0
# 37    37.0
# Name: Age, dtype: float64

# %% [markdown]
# ## dropping rows

# %%
a.drop(index=2)
# Out:
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 1     AZIZ   30      M    35000.0     TEACHER
# 3   naveed   30      F    70000.0     ANALYST
# 4    babar   25      M  1500000.0    ENGINEER
# 5     aqsa   22      F        NaN   SCIENTIST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %%
a.drop(index=[1,2])
# Out:
#       Name  Age gender     salary DESIGNATION
# 0  Mukhtar   37      M   115000.0   PROFESSOR
# 3   naveed   30      F    70000.0     ANALYST
# 4    babar   25      M  1500000.0    ENGINEER
# 5     aqsa   22      F        NaN   SCIENTIST
# 6    rafia   29      F    20000.0     ANALYST
# 7    samra   26      F  1500000.0   SCIENTIST
# 8     eman   26      F    35000.0    ENGINEER

# %% [markdown]
# ## droping column

# %%
a.drop(columns=["Age"])
# Out:
#       Name gender     salary DESIGNATION
# 0  Mukhtar      M   115000.0   PROFESSOR
# 1     AZIZ      M    35000.0     TEACHER
# 2   mohsin      M    50000.0    ENGINEER
# 3   naveed      F    70000.0     ANALYST
# 4    babar      M  1500000.0    ENGINEER
# 5     aqsa      F        NaN   SCIENTIST
# 6    rafia      F    20000.0     ANALYST
# 7    samra      F  1500000.0   SCIENTIST
# 8     eman      F    35000.0    ENGINEER

# %%
a.drop(columns=["Age","salary"])
# Out:
#       Name gender DESIGNATION
# 0  Mukhtar      M   PROFESSOR
# 1     AZIZ      M     TEACHER
# 2   mohsin      M    ENGINEER
# 3   naveed      F     ANALYST
# 4    babar      M    ENGINEER
# 5     aqsa      F   SCIENTIST
# 6    rafia      F     ANALYST
# 7    samra      F   SCIENTIST
# 8     eman      F    ENGINEER
